# %% [markdown]
# # Isaac Sim App Launcher
#
# 1. Click the `Start App Launcher` button below to display the launcher UI.
# 2. Wait for the init process.
# 3. If the virtual desktop is not displayed, please click `Open Desktop in new Tab`.
# 4. Click the blue buttons to run the demos.
# 5. Mouse over the buttons can display the full bash scripts.
# 6. Click the `Source Code` buttons can open the python code in VSCODE. To run the isaacsim python code in debug mode, need to manually set the python (3.11) interpreter to `/mnt/dev-tools/isaac-sim-5.1/python.sh`
# 7. `Stop All` button can stop the running demos, or click the `Restart` button below to restart the UI and kill all processes.
# 8. To switch the Isaac Sim version, expand the code cell, modify the version number, and then click the `Restart` button.
# 9. The complete code of this UI is in [ultils.py](./utils.py), to add new buttons modify the `get_app_list` or `get_tools_list` function. To change the UI layout modify function `display_ui`.
#
# <button data-commandlinker-command="notebook:run-all-cells" class="jupyter-button" style="color: #fff;background-color: #1976d2;">Start App Launcher</button>
# <button data-commandlinker-command="terminal:create-new" data-commandlinker-args='{"cwd": "dev-tools"}' class="jupyter-button">Open a Terminal</button>
# <button data-commandlinker-command="notebook:restart-run-all" class="jupyter-button">Restart</button>

# %%
import os
# availabe versions: 4.5, 5.0, 5.1
os.environ["ISAACSIM_VERSION"] = "5.1"

from utils import *
from gpu_monitor import GPUMonitor

# Monitor GPU usage
gpu_monitor = GPUMonitor()

# Init remote desktop
display_desktop()

# Show UI buttons
display_ui()
# Out:
# HTML(value='')
# HTML(value='<a href="https://jupyter.dev.intel4coro.de//user/yxzhan-isaacsim-template-m8hea9w9/desktop"  class…
# ...
